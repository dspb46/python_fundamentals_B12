# %%
#Day5_b12

# %%
#list methods

# %%
my_students=['srinivasa','sandhya','nidhi','prasad','suhas','phani']

# %%
print(my_students)
# Out:
# ['srinivasa', 'sandhya', 'nidhi', 'prasad', 'suhas', 'phani']

# %%
type(my_students)
# Out:
# list

# %%
# To print the list in reverse order

# %%
my_students.reverse()

# %%
print(my_students)
# Out:
# ['phani', 'suhas', 'prasad', 'nidhi', 'sandhya', 'srinivasa']

# %%
my_students=['srinivasa','sandhya','nidhi','prasad','suhas','phani']

# %%
print(my_students)
# Out:
# ['srinivasa', 'sandhya', 'nidhi', 'prasad', 'suhas', 'phani']

# %%
print(my_students.reverse())
# Out:
# None

# %%
my_students.reverse()

# %%
print(my_students)
# Out:
# ['srinivasa', 'sandhya', 'nidhi', 'prasad', 'suhas', 'phani']

# %%
my_students.reverse()

# %%
print(my_students)
# Out:
# ['phani', 'suhas', 'prasad', 'nidhi', 'sandhya', 'srinivasa']

# %%
print(my_students.reverse())
# Out:
# None

# %%
print(my_students)
# Out:
# ['srinivasa', 'sandhya', 'nidhi', 'prasad', 'suhas', 'phani']

# %%
# to get the count of elements in the list

# %%
len (my_students)
# Out:
# 6

# %%
# Introduction to for loops:

# %%
#To split out the elements seperately

# %%
my_students=['srinivasa','sandhya','nidhi','prasad','suhas','phani']

# %%
print(my_students)
# Out:
# ['srinivasa', 'sandhya', 'nidhi', 'prasad', 'suhas', 'phani']

# %%
for students in my_students:
    print(students)
# Out:
# srinivasa
# sandhya
# nidhi
# prasad
# suhas
# phani

# %%
#*** For loop: create a temp var->student->can any name 
#Create the indentation-> after':'
