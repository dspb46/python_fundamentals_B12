# %%
#Day4_b12

# %%
#Adding, changing and removing elements from a list

# %%
my_students=['srinivasa','sandhya','nidhi','prasad','suhas','phani']

print(my_students)
# Out:
# ['srinivasa', 'sandhya', 'nidhi', 'prasad', 'suhas', 'phani']

# %%
# To add elements to the list

# %%
my_students.append('sriya')

# %%
#Append add the element to the end of the list

# %%
print(my_students)
# Out:
# ['srinivasa', 'sandhya', 'nidhi', 'prasad', 'suhas', 'phani', 'sriya']

# %%
type(my_students)
# Out:
# list

# %%
#To add a new element at specified index. Repalces the specified index

# %%
my_students[1]='chinna'

# %%
print(my_students)
# Out:
# ['srinivasa', 'chinna', 'nidhi', 'prasad', 'suhas', 'phani', 'sriya']

# %%
#Inserting an element into the list

# %%
my_students.insert(2,'sandhya')

# %%
print(my_students)
# Out:
# ['srinivasa', 'chinna', 'sandhya', 'nidhi', 'prasad', 'suhas', 'phani', 'sriya']

# %%
#To remove element from the list

# %%
del my_students[1]

# %%
print(my_students)
# Out:
# ['srinivasa', 'sandhya', 'nidhi', 'prasad', 'suhas', 'phani', 'sriya']

# %%
my_students.pop()
# Out:
# 'sriya'

# %%
print(my_students)
# Out:
# ['srinivasa', 'sandhya', 'nidhi', 'prasad', 'suhas', 'phani']

# %%
#removing element using pop() method. It will delete the element from the end as shown above

# %%
my_students.pop(4)
# Out:
# 'suhas'

# %%
#To delete a specified element using pop

# %%
print(my_students)
# Out:
# ['srinivasa', 'sandhya', 'nidhi', 'prasad', 'phani']

# %%
#Organising a list

# %%
my_students=['srinivasa','sandhya','nidhi','prasad','suhas','phani']

# %%
print(my_students)
# Out:
# ['srinivasa', 'sandhya', 'nidhi', 'prasad', 'suhas', 'phani']

# %%
# Arrange the array list in alphabetical order

# %%
my_students.sort()

# %%
print(my_students)
# Out:
# ['nidhi', 'phani', 'prasad', 'sandhya', 'srinivasa', 'suhas']

# %%
#this will make permanent changes to the list

# %%
#for temporary sorting

# %%
my_students=['srinivasa','sandhya','nidhi','prasad','suhas','phani']

# %%
print("This is the temporary sorted list")
print(sorted(my_students))
# Out:
# This is the temporary sorted list
# ['nidhi', 'phani', 'prasad', 'sandhya', 'srinivasa', 'suhas']

# %%
print(my_students)
# Out:
# ['srinivasa', 'sandhya', 'nidhi', 'prasad', 'suhas', 'phani']
